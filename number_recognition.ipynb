# %%
import tensorflow as tf
from keras.utils import np_utils
from matplotlib import pyplot as plt
import numpy as np 
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.utils import to_categorical

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
print('Training Images:{}'.format(x_train.shape))

print('Testing Images:{}'.format(x_test.shape))
# Out:
# Training Images:(60000, 28, 28)
# Testing Images:(10000, 28, 28)

# %%
print(x_train[0].shape)
# Out:
# (28, 28)

# %%
for i in range(234,238):
  plt.subplot(120+1+i)
  img=x_train[i]
  plt.imshow(img)
  plt.show()

# %%
# Preprocess the data
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1).astype('float32') / 255
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1).astype('float32') / 255
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=5, batch_size=128, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 469/469 [==============================] - 36s 75ms/step - loss: 0.2156 - accuracy: 0.9379 - val_loss: 0.0933 - val_accuracy: 0.9718
# Epoch 2/5
# 469/469 [==============================] - 33s 70ms/step - loss: 0.0700 - accuracy: 0.9790 - val_loss: 0.0596 - val_accuracy: 0.9805
# Epoch 3/5
# 469/469 [==============================] - 31s 67ms/step - loss: 0.0455 - accuracy: 0.9864 - val_loss: 0.0488 - val_accuracy: 0.9836
# Epoch 4/5
# 469/469 [==============================] - 34s 73ms/step - loss: 0.0343 - accuracy: 0.9900 - val_loss: 0.0465 - val_accuracy: 0.9844
# Epoch 5/5
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0251 - accuracy: 0.9927 - val_loss: 0.0442 - val_accuracy: 0.9850

# %%
# Make predictions
predictions = model.predict(x_test)
predicted_labels = np.argmax(predictions, axis=1)
# Out:
# 313/313 [==============================] - 2s 6ms/step

# %%
# Print the predicted images
fig, axes = plt.subplots(5, 5, figsize=(10, 10))
axes = axes.ravel()

for i in range(25):
    axes[i].imshow(x_test[i].reshape(28, 28), cmap='gray')
    axes[i].set_title('actual: %s \nPredict: %s' % (np.argmax(y_test[i]), predicted_labels[i]))
    axes[i].axis('off')

plt.subplots_adjust(hspace=0.5)
plt.show()
